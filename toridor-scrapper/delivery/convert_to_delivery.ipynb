# %%
import pandas as pd

# %%
class InfluencerConst:
    INFLUENCER_NAME="インフルエンサー名"
    NAME="発送先氏名"
    NAME_KANA="発送先氏名（カナ）"
    POSTAL_CODE="郵便番号"
    PREFECTURE="都道府県"
    CITY="市区町村"
    ADDRESS="番地"
    MANSION="マンション名"
    PHONE="電話番号"

class ResultConst:
    """
    配送先郵便番号	配送先都道府県	配送先住所	配送先マンション・ビル名	配送先氏名
    """
    PRODUCT_ID="商品ID"
    PRODUCT_NAME="商品名"
    PRODUCT_CODE="商品コード"
    PRODUCT_BLANK_LIST_1=[
        '軽減税率適用商品',
        'サイズ',
        '在庫数',
        '出庫依頼数',
        '出庫予約',
        '単価',
        '合計金額',
        '小計',
        '配送料',
        '手数料',
        '割引額',
        '総計',
        '総計通常税率',
        '総計軽減税率',
    ]
    POST_CODE="配送先郵便番号"
    PREFECTURE="配送先都道府県"
    ADDRESS="配送先住所"
    MANSION="配送先マンション・ビル名"
    NAME="配送先氏名"
    PRODUCT_BLANK_LIST_2_A=[
        '配送先会社名',
    ]
    PHONE_NUMBER='配送先電話番号'
    PRODUCT_BLANK_LIST_2_B=[
        '配送先連絡メール',
        '配送先マスタ登録',
        '注文番号',
        '配送便指定',
        '配送会社指定',
        '出庫希望日',
        'お届け希望日',
        '希望時間帯',
        '緩衝材指定',
        '緩衝材',
        'ギフトラッピング単位',
        'ラッピングタイプ',
        '贈り主氏名',
        '同梱指定',
        '不在時宅配ボックス',
        '割れ物注意',
    ]
    ATTACH_MESSAGE="明細書メッセージ"
    NOTIFY_MESSAGE="発送通知メッセージ"
    PRODUCT_BLANK_LIST_3=["明細書の同梱","明細書の金額印字"]
    SENDER_POST_CODE="ご依頼主郵便番号"
    SENDER_PREFECTURE="ご依頼主都道府県"
    SENDER_ADDRESS="ご依頼主住所"
    SENDER_MANSION="ご依頼主マンション・ビル名"
    SENDER_NAME="ご依頼主氏名"
    SENDER_COMPANY_NAME="ご依頼主会社名"
    PRODUCT_BLANK_LIST_4=["ご依頼主部署名"]
    ASK_CONTACT="お問い合わせ先"
    SENDER_PHONE="ご依頼主電話番号"
    SENDER_EMAIL="ご依頼主メールアドレス"
    PRODUCT_BLANK_LIST_5=["お問い合わせフォーム"]




INFLUENCER_FILE_NAME="toridori/influencer.csv"
RESULT_FILE_NAME="openlogi/result.csv"

PRODUCT_ID="1"
PRODUCT_NAME="Xiphos バックパック MK-I"
PRODUCT_CODE="BPK000001BL1"
ATTACH_MESSAGE = "\n".join([
    "Xiphosを選んでいただき、誠にありがとうございます。",
    "私たちの製品がお客様の日常生活にお役立ちできることを大変うれしく思っております。",
    "",
    "また、より良い未来を実現するために努力し、お客様と共に歩んでいけることを誇りに思っています。",
    "",
    "今後とも、Xiphosのご利用に関するサポートを引き続きよろしくお願い申し上げます。製品のお届けまでには少しお時間をいただきますが、ぜひお楽しみにしてください。",
])
NOTIFY_MESSAGE="\n".join([
    "Xiphos の商品をご購入いただき、誠にありがとうございます。お客様のご注文した商品が無事に発送されましたことをお知らせいたします。",
    "",
    "商品のお届けまでしばらくお待ちいただくこととなりますが、ご注文内容に誤りがないかご確認いただき、配送状況をご追跡いただければ幸いです。商品がお手元に届いた際には、ご満足いただけますことを願っております。",
    "",
    "何卒よろしくお願い申し上げます。",
])
"1070062	東京都	港区南青山2-2-15	WIN青山531	テックモ合同会社	テックモ合同会社"
SENDER_POST_CODE="1070062"
SENDER_PREFECTURE="東京都"
SENDER_ADDRESS="港区南青山2-2-15"
SENDER_MANSION="WIN青山531"
SENDER_NAME="テックモ合同会社"
SENDER_COMPANY_NAME="テックモ合同会社"
ASK_CONTACT="EMAIL"
SENDER_PHONE="05058962637"
SENDER_EMAIL="support@xiphosbag.com"

# %%
df = pd.read_csv(INFLUENCER_FILE_NAME)
df.head()

# %%
df2 = pd.DataFrame()

# %%
df2[ResultConst.PRODUCT_ID] = [PRODUCT_ID] * len(df)
df2[ResultConst.PRODUCT_NAME] = PRODUCT_NAME
df2[ResultConst.PRODUCT_CODE] = PRODUCT_CODE
df2[ResultConst.PRODUCT_BLANK_LIST_1] = ""
df2[ResultConst.POST_CODE] = df[InfluencerConst.POSTAL_CODE]
df2[ResultConst.PREFECTURE] = df[InfluencerConst.PREFECTURE]
df2[ResultConst.ADDRESS] = df[InfluencerConst.CITY] + df[InfluencerConst.ADDRESS]
df2[ResultConst.MANSION] = df[InfluencerConst.MANSION]
df2[ResultConst.NAME] = df[InfluencerConst.NAME]
df2[ResultConst.PRODUCT_BLANK_LIST_2_A] = ""
df2[ResultConst.PHONE_NUMBER] = df[InfluencerConst.PHONE]
df2[ResultConst.PRODUCT_BLANK_LIST_2_B] = ""
df2[ResultConst.ATTACH_MESSAGE] = ATTACH_MESSAGE
df2[ResultConst.NOTIFY_MESSAGE] = NOTIFY_MESSAGE
df2[ResultConst.PRODUCT_BLANK_LIST_3] = ""
df2[ResultConst.SENDER_POST_CODE] = SENDER_POST_CODE
df2[ResultConst.SENDER_PREFECTURE] = SENDER_PREFECTURE
df2[ResultConst.SENDER_ADDRESS] = SENDER_ADDRESS
df2[ResultConst.SENDER_MANSION] = SENDER_MANSION
df2[ResultConst.SENDER_NAME] = SENDER_NAME
df2[ResultConst.SENDER_COMPANY_NAME] = SENDER_COMPANY_NAME
df2[ResultConst.PRODUCT_BLANK_LIST_4] = ""
df2[ResultConst.ASK_CONTACT] = ASK_CONTACT
df2[ResultConst.SENDER_PHONE] = SENDER_PHONE
df2[ResultConst.SENDER_EMAIL] = SENDER_EMAIL
df2[ResultConst.PRODUCT_BLANK_LIST_5] = ""

# %%
df2

# %%
df2.to_csv(RESULT_FILE_NAME, index=False)

# %%
# !open $RESULT_FILE_NAME
